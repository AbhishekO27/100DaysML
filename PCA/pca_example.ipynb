# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris

# Load example dataset: Iris (4 features)
iris = load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names

# Create DataFrame for easier handling
df = pd.DataFrame(X, columns=feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

print("Shape before PCA:", X_scaled.shape)
print("Shape after PCA:", X_pca.shape)
# Out:
# Shape before PCA: (150, 4)
# Shape after PCA: (150, 2)

# %%
explained_variance = pca.explained_variance_ratio_
print("Explained variance ratio:", explained_variance)
print("Total variance explained:", explained_variance.sum())
# Out:
# Explained variance ratio: [0.72962445 0.22850762]
# Total variance explained: 0.9581320720000166

# %%
plt.figure(figsize=(8,6))
scatter = plt.scatter(X_pca[:,0], X_pca[:,1], c=y, cmap='viridis', edgecolor='k', s=50)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA on Iris Dataset")
plt.legend(handles=scatter.legend_elements()[0], labels=iris.target_names)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 6
#       4 plt.ylabel("Principal Component 2")
#       5 plt.title("PCA on Iris Dataset")
# ----> 6 plt.legend(handles=scatter.legend_elements()[0], labels=iris.target_names)
#       7 plt.grid(True)
#       8 plt.show()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\pyplot.py:3588, in legend(*args, **kwargs)
#    3586 @_copy_docstring_and_deprecators(Axes.legend)
#    3587 def legend(*args, **kwargs) -> Legend:
# -> 3588     return gca().legend(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\axes\_axes.py:341, in Axes.legend(self, *args, **kwargs)
#     223 @_docstring.dedent_interpd
#     224 def legend(self, *args, **kwargs):
#     225     """
#     226     Place a legend on the Axes.
#     227
#    (...)
#     339     .. plot:: gallery/text_labels_and_annotations/legend.py
#     340     """
# --> 341     handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
#     342     self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     343     self.legend_._remove_method = self._remove_legend
#
# File ~\AppData\Roaming\Python\Python312\site-packages\matplotlib\legend.py:1350, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1346     _api.warn_external(f"Mismatched number of handles and labels: "
#    1347                        f"len(handles) = {len(handles)} "
#    1348                        f"len(labels) = {len(labels)}")
#    1349 # if got both handles and labels as kwargs, make same length
# -> 1350 if handles and labels:
#    1351     handles, labels = zip(*zip(handles, labels))
#    1353 elif handles is not None and labels is None:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
import seaborn as sns
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()
df_iris = pd.DataFrame(iris.data, columns=iris.feature_names)
df_iris['species'] = iris.target

sns.pairplot(df_iris, hue='species', corner=True)
